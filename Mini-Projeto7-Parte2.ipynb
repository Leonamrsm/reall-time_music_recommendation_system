# %% [markdown]
# # <font color='blue'>Data Science Academy</font>
# # <font color='blue'>Big Data Real-Time Analytics com Python e Spark</font>
#
# ## <font color='blue'>Mini-Projeto 7</font>
#
# ### <font color='blue'>Sistema de Recomendação em Tempo Real com Machine Learning, PySpark, Spark Streaming e Kafka</font>

# %% [markdown]
# ![title](imagens/MP7.png)

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())

# %%
# Para atualizar um pacote, execute o comando abaixo no terminal ou prompt de comando:
# pip install -U nome_pacote

# Para instalar a versão exata de um pacote, execute o comando abaixo no terminal ou prompt de comando:
#!pip install nome_pacote==versão_desejada

# Depois de instalar ou atualizar o pacote, reinicie o jupyter notebook.

# Instala o pacote watermark. 
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
#!pip install -q -U watermark

# %%
# Imports
import os
import time
import random
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.ml.feature import Normalizer, StandardScaler

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Data Science Academy" --iversions
# Out:
# Author: Data Science Academy
#
# sys    : 3.10.9 (main, Mar  1 2023, 18:23:06) [GCC 11.2.0]
# pyspark: 3.3.2

# %%
# Endereço do servidor Kafka
SERVER = 'localhost:9092'

# %%
# Nome do tópico
TOPIC = "dsaminiprojeto7"

# %%
# Conectores do Spark para o Apache Kafka
# jar (java archive), é um arquivo compactado que contém classes java.
spark_jars =  ("{},{},{},{},{}".format(os.getcwd() + "/jars/spark-sql-kafka-0-10_2.12-3.2.1.jar",  
                                       os.getcwd() + "/jars/kafka-clients-2.1.1.jar", 
                                       os.getcwd() + "/jars/spark-streaming-kafka-0-10-assembly_2.12-3.3.2.jar", 
                                       os.getcwd() + "/jars/commons-pool2-2.8.0.jar",  
                                       os.getcwd() + "/jars/spark-token-provider-kafka-0-10_2.12-3.1.2.jar"))

# %%
# Inicializa sessão Spark
spark = SparkSession \
        .builder \
        .config("spark.jars", spark_jars) \
        .appName("Mini-Projeto7") \
        .getOrCreate()
# Out:
# 23/07/20 05:15:36 WARN Utils: Your hostname, leonam-pc resolves to a loopback address: 127.0.1.1; using 192.168.15.37 instead (on interface wlx64700215b737)
# 23/07/20 05:15:36 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 23/07/20 05:15:37 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
spark.sparkContext.setLogLevel("ERROR")

# %%
# Usamos o Spark Streaming para leitura do streaming de dados do Kafka e salvamos em um dataframe
df = spark \
        .readStream \
        .format("kafka") \
        .option("kafka.bootstrap.servers", SERVER) \
        .option("subscribe", TOPIC) \
        .option("startingOffsets", "latest") \
        .load()

# %%
df.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
# Selecionamos a coluna timestamp como string e salvamos em um novo dataframe
df1 = df.selectExpr("CAST(value AS STRING)", "timestamp") 
df1.printSchema()
# Out:
# root
#  |-- value: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)

# %%
# Definimos o schema com o nome de cada coluna e o tipo de dado
def_schema = "order_id INT, id STRING, name STRING, popularity INT, duration_ms DOUBLE, " \
             + "artists STRING, id_artists STRING, release_date STRING, " \
             + "danceability DOUBLE,energy DOUBLE, key INT, loudness DOUBLE, " \
             + "mode INT,speechiness DOUBLE," \
             + "acousticness DOUBLE, instrumentalness DOUBLE, liveness DOUBLE, " \
             + "valence DOUBLE, tempo DOUBLE, time_signature DOUBLE"

# %%
# Selecionamos o streaming de dados de acordo com o schema e salvamos em um novo dataframe
df2 = df1.select(from_csv(col("value"), def_schema).alias("song"), "timestamp")
df2.printSchema()
# Out:
# root
#  |-- song: struct (nullable = true)
#  |    |-- order_id: integer (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- popularity: integer (nullable = true)
#  |    |-- duration_ms: double (nullable = true)
#  |    |-- artists: string (nullable = true)
#  |    |-- id_artists: string (nullable = true)
#  |    |-- release_date: string (nullable = true)
#  |    |-- danceability: double (nullable = true)
#  |    |-- energy: double (nullable = true)
#  |    |-- key: integer (nullable = true)
#  |    |-- loudness: double (nullable = true)
#  |    |-- mode: integer (nullable = true)
#  |    |-- speechiness: double (nullable = true)
#  |    |-- acousticness: double (nullable = true)
#  |    |-- instrumentalness: double (nullable = true)
#  |    |-- liveness: double (nullable = true)
#  |    |-- valence: double (nullable = true)
#  |    |-- tempo: double (nullable = true)
#  |    |-- time_signature: double (nullable = true)
#  |-- timestamp: timestamp (nullable = true)

# %%
# Criamos uma view na memória do Spark e visualizamos o schema
df3 = df2.select("song.*", "timestamp")  
df3.createOrReplaceTempView("df3_View");
df3.printSchema()
# Out:
# root
#  |-- order_id: integer (nullable = true)
#  |-- id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- popularity: integer (nullable = true)
#  |-- duration_ms: double (nullable = true)
#  |-- artists: string (nullable = true)
#  |-- id_artists: string (nullable = true)
#  |-- release_date: string (nullable = true)
#  |-- danceability: double (nullable = true)
#  |-- energy: double (nullable = true)
#  |-- key: integer (nullable = true)
#  |-- loudness: double (nullable = true)
#  |-- mode: integer (nullable = true)
#  |-- speechiness: double (nullable = true)
#  |-- acousticness: double (nullable = true)
#  |-- instrumentalness: double (nullable = true)
#  |-- liveness: double (nullable = true)
#  |-- valence: double (nullable = true)
#  |-- tempo: double (nullable = true)
#  |-- time_signature: double (nullable = true)
#  |-- timestamp: timestamp (nullable = true)

# %%
# Selecionamos os dados com as músicas do stream
musicas_stream = spark.sql("SELECT * FROM df3_View")

# %%
# Não podemos visualizar ainda, pois temos que gerar o stream do Spark Streaming
# musicas_stream.show()

# %%
# Criamos o stream de dados no Spark Streaming
musicas_stream_spark = musicas_stream \
        .writeStream \
        .trigger(processingTime = '5 seconds') \
        .outputMode("append") \
        .option("truncate", "false") \
        .format("memory") \
        .queryName("tabela_spark") \
        .start()

musicas_stream_spark.awaitTermination(1)
# Out:
# False

# %%
# Selecionamos as músicas da tabela de stream do Spark
spark_songs = spark.sql("SELECT * FROM tabela_spark")

# %%
# Agora sim podemos visualizar o stream em tempo real como tabela do Spark
spark_songs.show(5)
# Out:
# +--------+--------------------+----------+----------+-----------+--------------------+--------------------+------------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+--------------------+
# |order_id|                  id|      name|popularity|duration_ms|             artists|          id_artists|release_date|danceability|energy|key|loudness|mode|speechiness|acousticness|instrumentalness|liveness|valence|  tempo|time_signature|           timestamp|
# +--------+--------------------+----------+----------+-----------+--------------------+--------------------+------------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+--------------------+
# |     606|65qxSIjP13dioahJb...| sUpa Ugly|         0|   196897.0|         GodDamnChan|   AvHXmhShvORtjrNQK|  2018-02-23|       0.602| 0.681|  2| -12.059|   1|     0.0648|       0.634|           0.806|   0.086|  0.318| 64.994|           4.0|2023-07-20 05:15:...|
# |     607|5UTbwnxRh9DUFMKHS...|      Dusk|         0|   255233.0|        WhyspBaribal|SJGSpcTbSYsBwHWfw...|  2018-02-15|       0.732| 0.302|  1| -14.041|   1|      0.186|       0.617|           0.272|   0.118|  0.236| 90.042|           4.0|2023-07-20 05:15:...|
# |     608|29MyHIVuh2jrMIxFO...|Give It Up|        17|   159252.0|YannLaurenWolfski...|XaqXXVsPWHhrAtjgX...|  2018-02-16|       0.887| 0.441|  8|  -7.192|   1|      0.154|       0.177|             0.0|   0.149|   0.45|107.065|           4.0|2023-07-20 05:15:...|
# +--------+--------------------+----------+----------+-----------+--------------------+--------------------+------------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+--------------------+

# %%
# Podemos visualizar apenas algumas colunas, por exemplo
spark_songs.select('order_id', 'id', 'name', 'popularity', 'duration_ms', 'artists').show(5)
# Out:
# +--------+--------------------+--------------------+----------+-----------+--------------------+
# |order_id|                  id|                name|popularity|duration_ms|             artists|
# +--------+--------------------+--------------------+----------+-----------+--------------------+
# |     606|65qxSIjP13dioahJb...|           sUpa Ugly|         0|   196897.0|         GodDamnChan|
# |     607|5UTbwnxRh9DUFMKHS...|                Dusk|         0|   255233.0|        WhyspBaribal|
# |     608|29MyHIVuh2jrMIxFO...|          Give It Up|        17|   159252.0|YannLaurenWolfski...|
# |     609|5YREQJO8jVZSCW1Mp...|Fight or Flight Club|         0|   151117.0|               Madge|
# |     610|68PgM3ORNYfhr9iO9...|         Blue Cheese|         0|   266181.0|             ChezAli|
# +--------+--------------------+--------------------+----------+-----------+--------------------+
# only showing top 5 rows

# %%
# Contagem de músicas extraídas em tempo real
spark_songs.count()
# Out:
# 23

# %% [markdown]
# Aguarde alguns minutos antes de seguir com a execução para que o streaming de dados possa ser coletado.

# %% [markdown]
# > Vamos agora trabalhar na extração de dados do Spotify.

# %%
# https://pypi.org/project/spotipy/
# !pip install -q spotipy

# %%
# Imports
import os
import ujson
import spotipy
import spotipy.util
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.feature import StandardScaler
from pyspark.ml.clustering import KMeans
from pyspark.ml.evaluation import ClusteringEvaluator
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import warnings
import random
warnings.filterwarnings("ignore")

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Data Science Academy" --iversions
# Out:
# Author: Data Science Academy
#
# matplotlib: 3.7.0
# sys       : 3.10.9 (main, Mar  1 2023, 18:23:06) [GCC 11.2.0]
# pyspark   : 3.3.2
# seaborn   : 0.12.2
# pandas    : 1.5.3
# spotipy   : 2.23.0
# numpy     : 1.23.5
# ujson     : 5.4.0

# %% [markdown]
# Leia o manual em pdf no Capítulo 16 do curso com os detalhes sobre a criação da API.

# %%
# Aqui você coloca as suas chaves da API do Spotify
os.environ["SPOTIPY_CLIENT_ID"] = 'inclua_aqui_seu_client_id'
os.environ["SPOTIPY_CLIENT_SECRET"] = 'inclua_aqui_seu_client_secret'
os.environ["SPOTIPY_REDIRECT_URI"] = 'http://localhost:7777/callback'

# %% [markdown]
# https://developer.spotify.com/documentation/general/guides/authorization/scopes/

# %%
# Escopo de extração das preferências do usuário
scope = 'user-library-read'

# %%
# Username no Spotify
username = 'inclua_aqui_seu_email_spotify'

# %%
# Criação do tohen de acesso
token = spotipy.util.prompt_for_user_token(username, scope)

# %%
# Cria o objeto de autenticação
spotipy_obj = spotipy.Spotify(auth = token)

# %%
# Extrai até 50 músicas da lista de favoritos do usuário
saved_tracks = spotipy_obj.current_user_saved_tracks(limit = 50)

# %%
saved_tracks
# Out:
# {'href': 'https://api.spotify.com/v1/me/tracks?offset=0&limit=50',
#  'items': [{'added_at': '2023-07-20T06:41:06Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Iyvo65peG4ImDz5AzTqQB'},
#        'href': 'https://api.spotify.com/v1/artists/4Iyvo65peG4ImDz5AzTqQB',
#        'id': '4Iyvo65peG4ImDz5AzTqQB',
#        'name': 'Element Eighty',
#        'type': 'artist',
#        'uri': 'spotify:artist:4Iyvo65peG4ImDz5AzTqQB'}],
#      'available_markets': ['AD',
#       'AG',
#       'AR',
#       'AT',
#       'BD',
#       'BE',
#       'BG',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BT',
#       'BW',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DM',
#       'DO',
#       'EC',
#       'EE',
#       'ES',
#       'FI',
#       'FM',
#       'FR',
#       'GB',
#       'GD',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IT',
#       'JP',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'LA',
#       'LC',
#       'LI',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'MH',
#       'ML',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'PA',
#       'PE',
#       'PH',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'RO',
#       'RW',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TH',
#       'TL',
#       'TO',
#       'TR',
#       'TV',
#       'TW',
#       'UA',
#       'US',
#       'VC',
#       'VE',
#       'VN',
#       'WS',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1kWR9RXEeXaSnK4VkRGEHn'},
#      'href': 'https://api.spotify.com/v1/albums/1kWR9RXEeXaSnK4VkRGEHn',
#      'id': '1kWR9RXEeXaSnK4VkRGEHn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731ad907758cd83044c5909bac',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021ad907758cd83044c5909bac',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511ad907758cd83044c5909bac',
#        'width': 64}],
#      'name': 'Element Eighty',
#      'release_date': '2003-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:1kWR9RXEeXaSnK4VkRGEHn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Iyvo65peG4ImDz5AzTqQB'},
#       'href': 'https://api.spotify.com/v1/artists/4Iyvo65peG4ImDz5AzTqQB',
#       'id': '4Iyvo65peG4ImDz5AzTqQB',
#       'name': 'Element Eighty',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Iyvo65peG4ImDz5AzTqQB'}],
#     'available_markets': ['AD',
#      'AG',
#      'AR',
#      'AT',
#      'BD',
#      'BE',
#      'BG',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BT',
#      'BW',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DM',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FM',
#      'FR',
#      'GB',
#      'GD',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IT',
#      'JP',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'LA',
#      'LC',
#      'LI',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MH',
#      'ML',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MW',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'RO',
#      'RW',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TH',
#      'TL',
#      'TO',
#      'TR',
#      'TV',
#      'TW',
#      'UA',
#      'US',
#      'VC',
#      'VE',
#      'VN',
#      'WS',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 197933,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUR10300935'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2YnvR7uhlWpPdYUn1eR25y'},
#     'href': 'https://api.spotify.com/v1/tracks/2YnvR7uhlWpPdYUn1eR25y',
#     'id': '2YnvR7uhlWpPdYUn1eR25y',
#     'is_local': False,
#     'name': 'Broken Promises',
#     'popularity': 55,
#     'preview_url': None,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2YnvR7uhlWpPdYUn1eR25y'}},
#   {'added_at': '2023-07-20T06:39:37Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5bf6yYgHODBW5EreBZshpX'},
#        'href': 'https://api.spotify.com/v1/artists/5bf6yYgHODBW5EreBZshpX',
#        'id': '5bf6yYgHODBW5EreBZshpX',
#        'name': 'Styles Of Beyond',
#        'type': 'artist',
#        'uri': 'spotify:artist:5bf6yYgHODBW5EreBZshpX'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0GmGQmKKOK16cPu1wYINzn'},
#        'href': 'https://api.spotify.com/v1/artists/0GmGQmKKOK16cPu1wYINzn',
#        'id': '0GmGQmKKOK16cPu1wYINzn',
#        'name': 'Grant Mohrman',
#        'type': 'artist',
#        'uri': 'spotify:artist:0GmGQmKKOK16cPu1wYINzn'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6NBlbzn0zAmJqet4aTy1JM'},
#      'href': 'https://api.spotify.com/v1/albums/6NBlbzn0zAmJqet4aTy1JM',
#      'id': '6NBlbzn0zAmJqet4aTy1JM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b3c3024cdbdf622459d0e7ac',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b3c3024cdbdf622459d0e7ac',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b3c3024cdbdf622459d0e7ac',
#        'width': 64}],
#      'name': 'Nine Thou (Grant Mohrman Superstars Remix)',
#      'release_date': '2007-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6NBlbzn0zAmJqet4aTy1JM'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5bf6yYgHODBW5EreBZshpX'},
#       'href': 'https://api.spotify.com/v1/artists/5bf6yYgHODBW5EreBZshpX',
#       'id': '5bf6yYgHODBW5EreBZshpX',
#       'name': 'Styles Of Beyond',
#       'type': 'artist',
#       'uri': 'spotify:artist:5bf6yYgHODBW5EreBZshpX'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0GmGQmKKOK16cPu1wYINzn'},
#       'href': 'https://api.spotify.com/v1/artists/0GmGQmKKOK16cPu1wYINzn',
#       'id': '0GmGQmKKOK16cPu1wYINzn',
#       'name': 'Grant Mohrman',
#       'type': 'artist',
#       'uri': 'spotify:artist:0GmGQmKKOK16cPu1wYINzn'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 243061,
#     'explicit': False,
#     'external_ids': {'isrc': 'USHM80779813'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4oDynzwp2QDey7zDS9TGft'},
#     'href': 'https://api.spotify.com/v1/tracks/4oDynzwp2QDey7zDS9TGft',
#     'id': '4oDynzwp2QDey7zDS9TGft',
#     'is_local': False,
#     'name': 'Nine Thou - Grant Mohrman Superstars Remix',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ba6447a65e1b168b41eb0b568db0e93c75f9bcec?cid=361c95d9763b4ef4b1bc4c15bacdcbb6',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4oDynzwp2QDey7zDS9TGft'}},
#   {'added_at': '2023-07-20T06:38:59Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Mbx4nuDeMZyg19xMibJIA'},
#        'href': 'https://api.spotify.com/v1/artists/3Mbx4nuDeMZyg19xMibJIA',
#        'id': '3Mbx4nuDeMZyg19xMibJIA',
#        'name': 'SOSKA 69',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Mbx4nuDeMZyg19xMibJIA'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/09b0XEidCqsRKik2Wq8QUM'},
#      'href': 'https://api.spotify.com/v1/albums/09b0XEidCqsRKik2Wq8QUM',
#      'id': '09b0XEidCqsRKik2Wq8QUM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b757afabeb43b101e46aaae6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b757afabeb43b101e46aaae6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b757afabeb43b101e46aaae6',
#        'width': 64}],
#      'name': 'Басы долбят',
#      'release_date': '2022-10-28',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:09b0XEidCqsRKik2Wq8QUM'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Mbx4nuDeMZyg19xMibJIA'},
#       'href': 'https://api.spotify.com/v1/artists/3Mbx4nuDeMZyg19xMibJIA',
#       'id': '3Mbx4nuDeMZyg19xMibJIA',
#       'name': 'SOSKA 69',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Mbx4nuDeMZyg19xMibJIA'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 144000,
#     'explicit': True,
#     'external_ids': {'isrc': 'RUA3R2147153'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3oZObqxgEjNuCiFfE11szK'},
#     'href': 'https://api.spotify.com/v1/tracks/3oZObqxgEjNuCiFfE11szK',
#     'id': '3oZObqxgEjNuCiFfE11szK',
#     'is_local': False,
#     'name': 'Басы долбят',
#     'popularity': 61,
#     'preview_url': 'https://p.scdn.co/mp3-preview/388faf2a9dd40b56f03bf84d678e3323982ceccf?cid=361c95d9763b4ef4b1bc4c15bacdcbb6',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3oZObqxgEjNuCiFfE11szK'}},
#   {'added_at': '2023-07-20T06:37:23Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KDuKk6YdEu3hR56HtXmxt'},
#        'href': 'https://api.spotify.com/v1/artists/0KDuKk6YdEu3hR56HtXmxt',
#        'id': '0KDuKk6YdEu3hR56HtXmxt',
#        'name': 'Story Of The Year',
#        'type': 'artist',
#        'uri': 'spotify:artist:0KDuKk6YdEu3hR56HtXmxt'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4juejyEeCKFskkDA6zhIBW'},
#      'href': 'https://api.spotify.com/v1/albums/4juejyEeCKFskkDA6zhIBW',
#      'id': '4juejyEeCKFskkDA6zhIBW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734b63a12a9a503c41c4a60836',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024b63a12a9a503c41c4a60836',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514b63a12a9a503c41c4a60836',
#        'width': 64}],
#      'name': 'Page Avenue',
#      'release_date': '2003-09-16',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:4juejyEeCKFskkDA6zhIBW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KDuKk6YdEu3hR56HtXmxt'},
#       'href': 'https://api.spotify.com/v1/artists/0KDuKk6YdEu3hR56HtXmxt',
#       'id': '0KDuKk6YdEu3hR56HtXmxt',
#       'name': 'Story Of The Year',
#       'type': 'artist',
#       'uri': 'spotify:artist:0KDuKk6YdEu3hR56HtXmxt'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 193106,
#     'explicit': False,
#     'external_ids': {'isrc': 'USMV20300128'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3WsgkhWH001sMkbZVcjreS'},
#     'href': 'https://api.spotify.com/v1/tracks/3WsgkhWH001sMkbZVcjreS',
#     'id': '3WsgkhWH001sMkbZVcjreS',
#     'is_local': False,
#     'name': 'And the Hero Will Drown',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c7bed8c123a7096dea4c7f9d842af56695e48f0e?cid=361c95d9763b4ef4b1bc4c15bacdcbb6',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3WsgkhWH001sMkbZVcjreS'}},
#   {'added_at': '2023-07-13T22:25:40Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kLsCQ1gKvJmjmC8XbfqFE'},
#        'href': 'https://api.spotify.com/v1/artists/6kLsCQ1gKvJmjmC8XbfqFE',
#        'id': '6kLsCQ1gKvJmjmC8XbfqFE',
#        'name': 'VISXGE',
#        'type': 'artist',
#        'uri': 'spotify:artist:6kLsCQ1gKvJmjmC8XbfqFE'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4dWpLZBzW0M5FG3H3nbtTt'},
#      'href': 'https://api.spotify.com/v1/albums/4dWpLZBzW0M5FG3H3nbtTt',
#      'id': '4dWpLZBzW0M5FG3H3nbtTt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b26e4117778b03d1a76a43a3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b26e4117778b03d1a76a43a3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b26e4117778b03d1a76a43a3',
#        'width': 64}],
#      'name': 'IMMACULATE',
#      'release_date': '2022-05-22',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4dWpLZBzW0M5FG3H3nbtTt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kLsCQ1gKvJmjmC8XbfqFE'},
#       'href': 'https://api.spotify.com/v1/artists/6kLsCQ1gKvJmjmC8XbfqFE',
#       'id': '6kLsCQ1gKvJmjmC8XbfqFE',
#       'name': 'VISXGE',
#       'type': 'artist',
#       'uri': 'spotify:artist:6kLsCQ1gKvJmjmC8XbfqFE'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 140873,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZHNC2223145'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5Txeau6Fi96zS4THXUJ4w7'},
#     'href': 'https://api.spotify.com/v1/tracks/5Txeau6Fi96zS4THXUJ4w7',
#     'id': '5Txeau6Fi96zS4THXUJ4w7',
#     'is_local': False,
#     'name': 'IMMACULATE',
#     'popularity': 71,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b1bb7e3e072b878061f5549dba5d397fbcbd92e4?cid=361c95d9763b4ef4b1bc4c15bacdcbb6',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5Txeau6Fi96zS4THXUJ4w7'}},
#   {'added_at': '2023-07-13T04:54:37Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4k1ELeJKT1ISyDv8JivPpB'},
#        'href': 'https://api.spotify.com/v1/artists/4k1ELeJKT1ISyDv8JivPpB',
#        'id': '4k1ELeJKT1ISyDv8JivPpB',
#        'name': 'The Prodigy',
#        'type': 'artist',
#        'uri': 'spotify:artist:4k1ELeJKT1ISyDv8JivPpB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5c7coIRdQXVBZIAd2VqXux'},
#      'href': 'https://api.spotify.com/v1/albums/5c7coIRdQXVBZIAd2VqXux',
#      'id': '5c7coIRdQXVBZIAd2VqXux',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27389eb06a89ec7288b82131f54',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0289eb06a89ec7288b82131f54',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485189eb06a89ec7288b82131f54',
#        'width': 64}],
#      'name': 'Always Outnumbered, Never Outgunned',
#      'release_date': '2004-08-23',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5c7coIRdQXVBZIAd2VqXux'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4k1ELeJKT1ISyDv8JivPpB'},
#       'href': 'https://api.spotify.com/v1/artists/4k1ELeJKT1ISyDv8JivPpB',
#       'id': '4k1ELeJKT1ISyDv8JivPpB',
#       'name': 'The Prodigy',
#       'type': 'artist',
#       'uri': 'spotify:artist:4k1ELeJKT1ISyDv8JivPpB'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 236973,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBKS0461557'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3vc1sGOGAVxhx8S1kERqyn'},
#     'href': 'https://api.spotify.com/v1/tracks/3vc1sGOGAVxhx8S1kERqyn',
#     'id': '3vc1sGOGAVxhx8S1kERqyn',
#     'is_local': False,
#     'name': "You'll Be UNDER MY WHEELS",
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6f3011a052aa3316b3a2f3cd43408685d1d472ac?cid=361c95d9763b4ef4b1bc4c15bacdcbb6',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:3vc1sGOGAVxhx8S1kERqyn'}},
#   {'added_at': '2023-07-13T04:49:24Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5CE2IfdYZEQGIDsfiRm8SI'},
#        'href': 'https://api.spotify.com/v1/artists/5CE2IfdYZEQGIDsfiRm8SI',
#        'id': '5CE2IfdYZEQGIDsfiRm8SI',
#        'name': 'DJ Shadow',
#        'type': 'artist',
#        'uri': 'spotify:artist:5CE2IfdYZEQGIDsfiRm8SI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2wlbu0mOH83oAJUL2tVxcY'},
#      'href': 'https://api.spotify.com/v1/albums/2wlbu0mOH83oAJUL2tVxcY',
#      'id': '2wlbu0mOH83oAJUL2tVxcY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ad65f45b80610db422cc1858',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ad65f45b80610db422cc1858',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ad65f45b80610db422cc1858',
#        'width': 64}],
#      'name': 'Six Days',
#      'release_date': '2002-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:2wlbu0mOH83oAJUL2tVxcY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5CE2IfdYZEQGIDsfiRm8SI'},
#       'href': 'https://api.spotify.com/v1/artists/5CE2IfdYZEQGIDsfiRm8SI',
#       'id': '5CE2IfdYZEQGIDsfiRm8SI',
#       'name': 'DJ Shadow',
#       'type': 'artist',
#       'uri': 'spotify:artist:5CE2IfdYZEQGIDsfiRm8SI'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Mz5XE0kb1GBnbLQm2VbcO'},
#       'href': 'https://api.spotify.com/v1/artists/0Mz5XE0kb1GBnbLQm2VbcO',
#       'id': '0Mz5XE0kb1GBnbLQm2VbcO',
#       'name': 'Mos Def',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Mz5XE0kb1GBnbLQm2VbcO'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 232533,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAQH0200041'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6ifNuuYjiS5NdMabN4Jvrs'},
#     'href': 'https://api.spotify.com/v1/tracks/6ifNuuYjiS5NdMabN4Jvrs',
#     'id': '6ifNuuYjiS5NdMabN4Jvrs',
#     'is_local': False,
#     'name': 'Six Days - Remix',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/adb7f0981a39a93646b351671fb3e98e8d658f5d?cid=361c95d9763b4ef4b1bc4c15bacdcbb6',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6ifNuuYjiS5NdMabN4Jvrs'}},
#   {'added_at': '2023-07-13T00:05:14Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5TvFfw1MgSntdU9A7yncyA'},
#        'href': 'https://api.spotify.com/v1/artists/5TvFfw1MgSntdU9A7yncyA',
#        'id': '5TvFfw1MgSntdU9A7yncyA',
#        'name': 'Dxrk ダーク',
#        'type': 'artist',
#        'uri': 'spotify:artist:5TvFfw1MgSntdU9A7yncyA'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0doOTVLn5DctSLGftsar6T'},
#      'href': 'https://api.spotify.com/v1/albums/0doOTVLn5DctSLGftsar6T',
#      'id': '0doOTVLn5DctSLGftsar6T',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273144fcad8ffb348edefb9e851',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02144fcad8ffb348edefb9e851',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851144fcad8ffb348edefb9e851',
#        'width': 64}],
#      'name': 'RAVE',
#      'release_date': '2022-03-18',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0doOTVLn5DctSLGftsar6T'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5TvFfw1MgSntdU9A7yncyA'},
#       'href': 'https://api.spotify.com/v1/artists/5TvFfw1MgSntdU9A7yncyA',
#       'id': '5TvFfw1MgSntdU9A7yncyA',
# ...
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1EnZjgGD81emhSdq6adEKt'},
#       'href': 'https://api.spotify.com/v1/artists/1EnZjgGD81emhSdq6adEKt',
#       'id': '1EnZjgGD81emhSdq6adEKt',
#       'name': 'GRAVECHILL',
#       'type': 'artist',
#       'uri': 'spotify:artist:1EnZjgGD81emhSdq6adEKt'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 116129,
#     'explicit': False,
#     'external_ids': {'isrc': 'AEA0Q2149133'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1Y5MJnYsIi3Qlifvss4jPI'},
#     'href': 'https://api.spotify.com/v1/tracks/1Y5MJnYsIi3Qlifvss4jPI',
#     'id': '1Y5MJnYsIi3Qlifvss4jPI',
#     'is_local': False,
#     'name': 'Twilight',
#     'popularity': 78,
#     'preview_url': 'https://p.scdn.co/mp3-preview/47a099d560a24dfbf84fd0f672f0889053869f08?cid=361c95d9763b4ef4b1bc4c15bacdcbb6',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1Y5MJnYsIi3Qlifvss4jPI'}},
#   {'added_at': '2023-02-06T22:12:35Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4UwArHrn7xxZleV0q6OzwI'},
#        'href': 'https://api.spotify.com/v1/artists/4UwArHrn7xxZleV0q6OzwI',
#        'id': '4UwArHrn7xxZleV0q6OzwI',
#        'name': 'staplegun',
#        'type': 'artist',
#        'uri': 'spotify:artist:4UwArHrn7xxZleV0q6OzwI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0WQa2WyVWjNNiTB7ACrWwr'},
#      'href': 'https://api.spotify.com/v1/albums/0WQa2WyVWjNNiTB7ACrWwr',
#      'id': '0WQa2WyVWjNNiTB7ACrWwr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27345e58675b8c3378390e125f7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0245e58675b8c3378390e125f7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485145e58675b8c3378390e125f7',
#        'width': 64}],
#      'name': '|BONKERS|',
#      'release_date': '2022-08-02',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0WQa2WyVWjNNiTB7ACrWwr'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4UwArHrn7xxZleV0q6OzwI'},
#       'href': 'https://api.spotify.com/v1/artists/4UwArHrn7xxZleV0q6OzwI',
#       'id': '4UwArHrn7xxZleV0q6OzwI',
#       'name': 'staplegun',
#       'type': 'artist',
#       'uri': 'spotify:artist:4UwArHrn7xxZleV0q6OzwI'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 212335,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZK6H2257375'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2G23H0snYYKYqRlyFvVObS'},
#     'href': 'https://api.spotify.com/v1/tracks/2G23H0snYYKYqRlyFvVObS',
#     'id': '2G23H0snYYKYqRlyFvVObS',
#     'is_local': False,
#     'name': '|BONKERS|',
#     'popularity': 73,
#     'preview_url': 'https://p.scdn.co/mp3-preview/873602c11d1a5a618e9c378d21532e4f0579cd59?cid=361c95d9763b4ef4b1bc4c15bacdcbb6',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2G23H0snYYKYqRlyFvVObS'}},
#   {'added_at': '2023-02-05T13:42:51Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ja9cfKWW8Zj9aloyK8WuY'},
#        'href': 'https://api.spotify.com/v1/artists/5ja9cfKWW8Zj9aloyK8WuY',
#        'id': '5ja9cfKWW8Zj9aloyK8WuY',
#        'name': 'MoonDeity',
#        'type': 'artist',
#        'uri': 'spotify:artist:5ja9cfKWW8Zj9aloyK8WuY'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4zRjyCx4wMu480J7tac2Gm'},
#      'href': 'https://api.spotify.com/v1/albums/4zRjyCx4wMu480J7tac2Gm',
#      'id': '4zRjyCx4wMu480J7tac2Gm',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27333364d6b6fd36894f1a3b506',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0233364d6b6fd36894f1a3b506',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485133364d6b6fd36894f1a3b506',
#        'width': 64}],
#      'name': 'NEON BLADE',
#      'release_date': '2022-06-01',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4zRjyCx4wMu480J7tac2Gm'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ja9cfKWW8Zj9aloyK8WuY'},
#       'href': 'https://api.spotify.com/v1/artists/5ja9cfKWW8Zj9aloyK8WuY',
#       'id': '5ja9cfKWW8Zj9aloyK8WuY',
#       'name': 'MoonDeity',
#       'type': 'artist',
#       'uri': 'spotify:artist:5ja9cfKWW8Zj9aloyK8WuY'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 265263,
#     'explicit': True,
#     'external_ids': {'isrc': 'SE6QE2237231'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0iUrxveyNUBfj0cqjYEijt'},
#     'href': 'https://api.spotify.com/v1/tracks/0iUrxveyNUBfj0cqjYEijt',
#     'id': '0iUrxveyNUBfj0cqjYEijt',
#     'is_local': False,
#     'name': 'NEON BLADE',
#     'popularity': 82,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0cf232e81622ab4bbe08b07ef82b672212cb767e?cid=361c95d9763b4ef4b1bc4c15bacdcbb6',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0iUrxveyNUBfj0cqjYEijt'}}],
#  'limit': 50,
#  'next': 'https://api.spotify.com/v1/me/tracks?offset=50&limit=50',
#  'offset': 0,
#  'previous': None,
#  'total': 101}

# %%
# Número de músicas extraídas
n_tracks = saved_tracks['total']
print('Total de Tracks: %d ' % n_tracks)
# Out:
# Total de Tracks: 101

# %%
# Função para extrair os atributos da lista de músicas do usuário
def select_features(track_response):
    return {        
        'id': str(track_response['track']['id']),
        'name': str(track_response['track']['name']),
        'artists': [artist['name'] for artist in track_response['track']['artists']],
        'popularity': track_response['track']['popularity']
    }

# %%
# Aplica a função
tracks = [select_features(track) for track in saved_tracks['items']]

# %%
# Extrai os atributos das músicas preferidas do usuário
while saved_tracks['next']:
    saved_tracks = spotipy_obj.next(saved_tracks)
    tracks.extend([select_features(track) for track in saved_tracks['items']])

# %%
# Criamos o dataframe do pandas
df_tracks = pd.DataFrame(tracks)
pd.set_option('display.max_rows', len(tracks))
df_tracks['artists'] = df_tracks['artists'].apply(lambda artists: artists[0])

# %%
df_tracks.head(10)
# Out:
#                        id                                        name  \
# 0  2YnvR7uhlWpPdYUn1eR25y                             Broken Promises
# 1  4oDynzwp2QDey7zDS9TGft  Nine Thou - Grant Mohrman Superstars Remix
# 2  3oZObqxgEjNuCiFfE11szK                                 Басы долбят
# 3  3WsgkhWH001sMkbZVcjreS                     And the Hero Will Drown
# 4  5Txeau6Fi96zS4THXUJ4w7                                  IMMACULATE
# 5  3vc1sGOGAVxhx8S1kERqyn                   You'll Be UNDER MY WHEELS
# 6  6ifNuuYjiS5NdMabN4Jvrs                            Six Days - Remix
# 7  01kfSdF9zfcDLri5sSWEoL                                        RAVE
# 8  6wk8RkIpZ6mbQigwKPr1oW                                      Riders
# 9  4cpmqPshK5SbCuGEORAKUS               SUICIDE YEAR - RAIZHELL Remix
#
#              artists  popularity
# 0     Element Eighty          55
# 1   Styles Of Beyond          64
# 2           SOSKA 69          61
# 3  Story Of The Year          55
# 4             VISXGE          71
# 5        The Prodigy          56
# 6          DJ Shadow          67
# 7           Dxrk ダーク          85
# 8           onimanxd          68
# 9           WEEDMANE          56

# %%
# Dicionário para os atributos de áudio
audio_features = {}

# %%
# Extrai os atributos de áudio
for idd in df_tracks['id'].tolist():
    audio_features[idd] = spotipy_obj.audio_features(idd)[0]

# %%
# Adicionamos os atributos de áudio ao dataframe
df_tracks['acousticness'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['acousticness'])
df_tracks['speechiness'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['speechiness'])
df_tracks['key'] = df_tracks['id'].apply(lambda idd: str(audio_features[idd]['key']))
df_tracks['liveness'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['liveness'])
df_tracks['instrumentalness'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['instrumentalness'])
df_tracks['energy'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['energy'])
df_tracks['tempo'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['tempo'])
df_tracks['loudness'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['loudness'])
df_tracks['danceability'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['danceability'])
df_tracks['valence'] = df_tracks['id'].apply(lambda idd: audio_features[idd]['valence'])

# %%
df_tracks.head()
# Out:
#                        id                                        name  \
# 0  2YnvR7uhlWpPdYUn1eR25y                             Broken Promises
# 1  4oDynzwp2QDey7zDS9TGft  Nine Thou - Grant Mohrman Superstars Remix
# 2  3oZObqxgEjNuCiFfE11szK                                 Басы долбят
# 3  3WsgkhWH001sMkbZVcjreS                     And the Hero Will Drown
# 4  5Txeau6Fi96zS4THXUJ4w7                                  IMMACULATE
#
#              artists  popularity  acousticness  speechiness key  liveness  \
# 0     Element Eighty          55      0.004870        0.100   1    0.0385
# 1   Styles Of Beyond          64      0.002080        0.104   1    0.2630
# 2           SOSKA 69          61      0.003860        0.210   3    0.4740
# 3  Story Of The Year          55      0.000687        0.242   4    0.4030
# 4             VISXGE          71      0.001510        0.358   7    0.6610
#
#    instrumentalness  energy    tempo  loudness  danceability  valence
# 0          0.000014   0.947  173.625    -2.983         0.446    0.653
# 1          0.000000   0.874  107.934    -6.529         0.635    0.577
# 2          0.162000   0.726  130.039    -7.426         0.755    0.415
# 3          0.000000   0.985  100.223    -3.358         0.433    0.327
# 4          0.000005   0.385  117.931    -7.568         0.780    0.340

# %%
# Selecionamos uma música randomicamente
musica_randomica = random.randint(0,len(df_tracks)-1)
df_musica_randomica = df_tracks.head(musica_randomica)[-1:]
df_musica_randomica
# Out:
#                         id     name artists  popularity  acousticness  \
# 29  1niIoI0IVTswfNxdyzxc4U  Quarter    Fuel          41       0.00012
#
#     speechiness key  liveness  instrumentalness  energy    tempo  loudness  \
# 29       0.0919   2     0.254             0.683    0.93  120.118    -5.297
#
#     danceability  valence
# 29         0.422    0.201

# %%
# Músicas do streaming do Spark
spark_songs.show(5)
# Out:
# +--------------------+--------------------+----------+--------------------+------------+------+---+--------+-----------+------------+----------------+--------+-------+-------+
# |                  id|                name|popularity|             artists|danceability|energy|key|loudness|speechiness|acousticness|instrumentalness|liveness|valence|  tempo|
# +--------------------+--------------------+----------+--------------------+------------+------+---+--------+-----------+------------+----------------+--------+-------+-------+
# |65qxSIjP13dioahJb...|           sUpa Ugly|         0|         GodDamnChan|       0.602| 0.681|  2| -12.059|     0.0648|       0.634|           0.806|   0.086|  0.318| 64.994|
# |5UTbwnxRh9DUFMKHS...|                Dusk|         0|        WhyspBaribal|       0.732| 0.302|  1| -14.041|      0.186|       0.617|           0.272|   0.118|  0.236| 90.042|
# |29MyHIVuh2jrMIxFO...|          Give It Up|        17|YannLaurenWolfski...|       0.887| 0.441|  8|  -7.192|      0.154|       0.177|             0.0|   0.149|   0.45|107.065|
# |5YREQJO8jVZSCW1Mp...|Fight or Flight Club|         0|               Madge|       0.518| 0.873|  8|  -6.557|        0.2|       0.011|           0.151|   0.105|  0.639|150.029|
# |68PgM3ORNYfhr9iO9...|         Blue Cheese|         0|             ChezAli|       0.671| 0.454|  5| -10.255|     0.0271|       0.283|         1.89E-4|    0.11|  0.458| 82.506|
# +--------------------+--------------------+----------+--------------------+------------+------+---+--------+-----------+------------+----------------+--------+-------+-------+
# only showing top 5 rows

# %%
# Não precisamos mais dessas colunas
spark_songs = spark_songs.drop('order_id', 
                               'mode', 
                               'release_date', 
                               'id_artists',
                               'time_signature', 
                               'duration_ms',
                               'timestamp')

# %%
# Cria o dataframe com a música escolhida randomicamente
df_sp = spark.createDataFrame(df_musica_randomica)

# %%
# Concatena músicas do streaming do Spark com a música do Spotify
df = spark_songs.union(df_sp)

# %%
df.show(5)
# Out:
# +--------------------+--------------------+----------+--------------------+------------+------+---+--------+-----------+------------+----------------+--------+-------+-------+
# |                  id|                name|popularity|             artists|danceability|energy|key|loudness|speechiness|acousticness|instrumentalness|liveness|valence|  tempo|
# +--------------------+--------------------+----------+--------------------+------------+------+---+--------+-----------+------------+----------------+--------+-------+-------+
# |65qxSIjP13dioahJb...|           sUpa Ugly|         0|         GodDamnChan|       0.602| 0.681|  2| -12.059|     0.0648|       0.634|           0.806|   0.086|  0.318| 64.994|
# |5UTbwnxRh9DUFMKHS...|                Dusk|         0|        WhyspBaribal|       0.732| 0.302|  1| -14.041|      0.186|       0.617|           0.272|   0.118|  0.236| 90.042|
# |29MyHIVuh2jrMIxFO...|          Give It Up|        17|YannLaurenWolfski...|       0.887| 0.441|  8|  -7.192|      0.154|       0.177|             0.0|   0.149|   0.45|107.065|
# |5YREQJO8jVZSCW1Mp...|Fight or Flight Club|         0|               Madge|       0.518| 0.873|  8|  -6.557|        0.2|       0.011|           0.151|   0.105|  0.639|150.029|
# |68PgM3ORNYfhr9iO9...|         Blue Cheese|         0|             ChezAli|       0.671| 0.454|  5| -10.255|     0.0271|       0.283|         1.89E-4|    0.11|  0.458| 82.506|
# +--------------------+--------------------+----------+--------------------+------------+------+---+--------+-----------+------------+----------------+--------+-------+-------+
# only showing top 5 rows

# %%
df.count()
# Out:
# 353

# %% [markdown]
# ## Pré-Processamento dos Dados

# %%
# Preparamos o VectorAssembler
vetor = VectorAssembler(inputCols = ['danceability',
                                     'energy',
                                     'loudness',
                                     'speechiness',
                                     'acousticness',
                                     'instrumentalness',
                                     'liveness',
                                     'valence',
                                     'tempo'], 
                        outputCol = 'song_features')

# %%
# Descartamos valores inválidos
assembled = vetor.setHandleInvalid("skip").transform(df)

# %%
assembled.show(5)
# Out:
# +--------------------+--------------------+----------+--------------------+------------+------+---+--------+-----------+------------+----------------+--------+-------+-------+--------------------+
# |                  id|                name|popularity|             artists|danceability|energy|key|loudness|speechiness|acousticness|instrumentalness|liveness|valence|  tempo|       song_features|
# +--------------------+--------------------+----------+--------------------+------------+------+---+--------+-----------+------------+----------------+--------+-------+-------+--------------------+
# |65qxSIjP13dioahJb...|           sUpa Ugly|         0|         GodDamnChan|       0.602| 0.681|  2| -12.059|     0.0648|       0.634|           0.806|   0.086|  0.318| 64.994|[0.602,0.681,-12....|
# |5UTbwnxRh9DUFMKHS...|                Dusk|         0|        WhyspBaribal|       0.732| 0.302|  1| -14.041|      0.186|       0.617|           0.272|   0.118|  0.236| 90.042|[0.732,0.302,-14....|
# |29MyHIVuh2jrMIxFO...|          Give It Up|        17|YannLaurenWolfski...|       0.887| 0.441|  8|  -7.192|      0.154|       0.177|             0.0|   0.149|   0.45|107.065|[0.887,0.441,-7.1...|
# |5YREQJO8jVZSCW1Mp...|Fight or Flight Club|         0|               Madge|       0.518| 0.873|  8|  -6.557|        0.2|       0.011|           0.151|   0.105|  0.639|150.029|[0.518,0.873,-6.5...|
# |68PgM3ORNYfhr9iO9...|         Blue Cheese|         0|             ChezAli|       0.671| 0.454|  5| -10.255|     0.0271|       0.283|         1.89E-4|    0.11|  0.458| 82.506|[0.671,0.454,-10....|
# +--------------------+--------------------+----------+--------------------+------------+------+---+--------+-----------+------------+----------------+--------+-------+-------+--------------------+
# only showing top 5 rows

# %%
# Preparamos o padronizador
std = StandardScaler(inputCol = 'song_features', outputCol = 'standardized')

# %%
# Treinamos o padronizador
scale = std.fit(assembled)

# %%
# Dataframe com dados padronizados
df = scale.transform(assembled)

# %%
df.show(5)
# Out:
# +--------------------+--------------------+----------+--------------------+------------+------+---+--------+-----------+------------+----------------+--------+-------+-------+--------------------+--------------------+
# |                  id|                name|popularity|             artists|danceability|energy|key|loudness|speechiness|acousticness|instrumentalness|liveness|valence|  tempo|       song_features|        standardized|
# +--------------------+--------------------+----------+--------------------+------------+------+---+--------+-----------+------------+----------------+--------+-------+-------+--------------------+--------------------+
# |65qxSIjP13dioahJb...|           sUpa Ugly|         0|         GodDamnChan|       0.602| 0.681|  2| -12.059|     0.0648|       0.634|           0.806|   0.086|  0.318| 64.994|[0.602,0.681,-12....|[3.41857490170965...|
# |5UTbwnxRh9DUFMKHS...|                Dusk|         0|        WhyspBaribal|       0.732| 0.302|  1| -14.041|      0.186|       0.617|           0.272|   0.118|  0.236| 90.042|[0.732,0.302,-14....|[4.15680536221174...|
# |29MyHIVuh2jrMIxFO...|          Give It Up|        17|YannLaurenWolfski...|       0.887| 0.441|  8|  -7.192|      0.154|       0.177|             0.0|   0.149|   0.45|107.065|[0.887,0.441,-7.1...|[5.03700321896422...|
# |5YREQJO8jVZSCW1Mp...|Fight or Flight Club|         0|               Madge|       0.518| 0.873|  8|  -6.557|        0.2|       0.011|           0.151|   0.105|  0.639|150.029|[0.518,0.873,-6.5...|[2.94156445030831...|
# |68PgM3ORNYfhr9iO9...|         Blue Cheese|         0|             ChezAli|       0.671| 0.454|  5| -10.255|     0.0271|       0.283|         1.89E-4|    0.11|  0.458| 82.506|[0.671,0.454,-10....|[3.81040491536076...|
# +--------------------+--------------------+----------+--------------------+------------+------+---+--------+-----------+------------+----------------+--------+-------+-------+--------------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# ## Machine Learning com Aprendizado Não Supervisionado

# %%
# Cria o objeto do modelo
objeto_KMeans = KMeans(featuresCol = 'standardized', k = 3)

# %%
# Treina o modelo
modelo_KMeans = objeto_KMeans.fit(df)

# %%
# Previsões do modelo
df_output = modelo_KMeans.transform(df)

# %%
df_output.count()
# Out:
# 421

# %%
df_output.show(10)
# Out:
# +--------------------+--------------------+----------+--------------------+------------+------+---+--------+-----------+------------+----------------+--------+-------+-------+--------------------+--------------------+----------+
# |                  id|                name|popularity|             artists|danceability|energy|key|loudness|speechiness|acousticness|instrumentalness|liveness|valence|  tempo|       song_features|        standardized|prediction|
# +--------------------+--------------------+----------+--------------------+------------+------+---+--------+-----------+------------+----------------+--------+-------+-------+--------------------+--------------------+----------+
# |65qxSIjP13dioahJb...|           sUpa Ugly|         0|         GodDamnChan|       0.602| 0.681|  2| -12.059|     0.0648|       0.634|           0.806|   0.086|  0.318| 64.994|[0.602,0.681,-12....|[3.41857490170965...|         0|
# |5UTbwnxRh9DUFMKHS...|                Dusk|         0|        WhyspBaribal|       0.732| 0.302|  1| -14.041|      0.186|       0.617|           0.272|   0.118|  0.236| 90.042|[0.732,0.302,-14....|[4.15680536221174...|         0|
# |29MyHIVuh2jrMIxFO...|          Give It Up|        17|YannLaurenWolfski...|       0.887| 0.441|  8|  -7.192|      0.154|       0.177|             0.0|   0.149|   0.45|107.065|[0.887,0.441,-7.1...|[5.03700321896422...|         1|
# |5YREQJO8jVZSCW1Mp...|Fight or Flight Club|         0|               Madge|       0.518| 0.873|  8|  -6.557|        0.2|       0.011|           0.151|   0.105|  0.639|150.029|[0.518,0.873,-6.5...|[2.94156445030831...|         1|
# |68PgM3ORNYfhr9iO9...|         Blue Cheese|         0|             ChezAli|       0.671| 0.454|  5| -10.255|     0.0271|       0.283|         1.89E-4|    0.11|  0.458| 82.506|[0.671,0.454,-10....|[3.81040491536076...|         1|
# |20gdor2Dl8DBpmypi...|               Crypt|         0|          CoreyFlood|       0.705| 0.784| 11|  -8.352|     0.0371|      0.0569|           0.848|   0.138|    0.9|123.467|[0.705,0.784,-8.3...|[4.00348057426130...|         1|
# |7klE1YD1Heozq0cac...|          Middle Man|         0|       PleasureHeads|       0.505|  0.73|  4|  -6.002|     0.0307|     6.44E-6|         0.00192|   0.305|  0.549|127.949|[0.505,0.73,-6.00...|[2.86774140425810...|         1|
# |6JlQBrHGU2FTtyqR7...|              Homowo|        30|            BasaBasa|       0.585| 0.737|  2|  -8.037|     0.0383|     0.00381|          0.0643|   0.521|  0.826|131.161|[0.585,0.737,-8.0...|[3.32203707225938...|         1|
# |72qX8nDHdVI9nzqdo...|         Without You|         0|GURLSEllenAndreaW...|       0.468| 0.156|  1| -11.701|      0.128|       0.751|         8.97E-4|   0.117|  0.169|179.828|[0.468,0.156,-11....|[2.65762965780750...|         0|
# |1oCuSVUtVHStzq5fa...|   Nothing's Changed|         0|     IsaacWaddington|       0.732| 0.317|  8|  -9.899|     0.0783|       0.443|         5.96E-5|  0.0757|  0.503|  76.99|[0.732,0.317,-9.8...|[4.15680536221174...|         0|
# +--------------------+--------------------+----------+--------------------+------------+------+---+--------+-----------+------------+----------------+--------+-------+-------+--------------------+--------------------+----------+
# only showing top 10 rows

# %% [markdown]
# ## Sistema de Recomendação

# %%
# Classe
class RecoSystem():
    
    # Método construtor
    def __init__(self, data):
        self.data_ = data
    
    # Método de recomendação
    def Recomm(self, nome_musica, amount = 1):
        
        # Lista para as distâncias
        distancias = []
        
        # Seleciona a música
        song = self.data_[(self.data_.name.str.lower() == nome_musica.lower())].head(1).values[0]
        res_dt = self.data_[self.data_.name.str.lower() != nome_musica.lower()]
        
        # Loop para o cálculo das distâncias
        for i_song in tqdm(res_dt.values):
            
            # Inicializa a distância
            distancia = 0
            
            # Loop para calcular a distância
            for col in np.arange(len(res_dt.columns)):
                if not col in [0,1,2,14]:
                    distancia = distancia + np.absolute(float(song[col]) - float(i_song[col]))
            
            # Adiciona na lista de distâncias
            distancias.append(distancia)
        
        res_dt['distance'] = distancias
        res_dt = res_dt.sort_values('distance')
        
        columns = ['id','name', 
                   'artists', 
                   'acousticness', 
                   'liveness', 
                   'instrumentalness', 
                   'energy', 
                   'danceability', 
                   'valence']
        
        return res_dt[columns][:amount]

# %%
# Nomes das colunas
datalabel = df_output.select('id',
                             'name',
                             'artists',
                             'danceability',
                             'energy',
                             'key',
                             'loudness',
                             'speechiness',
                             'acousticness',
                             'instrumentalness',
                             'liveness',
                             'valence',
                             'tempo',
                             'prediction')

# %%
# Dataset final
df_final = datalabel.toPandas()
df_final.drop(df_final[df_final['artists'] == '0'].index, inplace = True)
df_final.drop_duplicates(inplace = True)
df_final.drop(df_final[df_final['danceability'] == 0.0000].index, inplace = True)
df_final.drop(df_final[df_final['liveness'] == 0.000].index, inplace = True)
df_final.drop(df_final[df_final['instrumentalness'] == 0.000000].index, inplace = True)
df_final.drop(df_final[df_final['energy'] == 0.0000].index, inplace = True)
df_final.drop(df_final[df_final['danceability'] == 0.000].index, inplace = True)
df_final.drop(df_final[df_final['valence'] == 0.000].index, inplace = True)

# %%
df_final.shape
# Out:
# (379, 14)

# %%
df_final.sample(5)
# Out:
#                          id                      name        artists  \
# 165  4pAcD7T540cRmPhpWlYcbQ        Song About A Dream      AlZanders
# 355  1TdtpAUTwx99XeEDULGVkE                      Ryso  PsychicHealth
# 393  4bO0oh8PS9lmvImY20X6ac  Trapped in Your Universe        FatCamp
# 418  6AwRgxSdb1Ly25nQWjCjzI         What You Gonna Do           Nemi
# 217  2HP4sePgGIRL243WsLfJtQ            That's My Girl    RakeemMiles
#
#      danceability  energy key  loudness  speechiness  acousticness  \
# 165         0.664   0.778   8    -9.757       0.0703         0.403
# 355         0.612   0.450   8   -18.505       0.0384         0.384
# 393         0.559   0.418   9   -10.914       0.0251         0.551
# 418         0.639   0.465   0    -8.634       0.1120         0.133
# 217         0.746   0.487  11    -7.491       0.3400         0.108
#
#      instrumentalness  liveness  valence    tempo  prediction
# 165          0.001970    0.0993   0.3200  124.513           1
# 355          0.826000    0.0876   0.0378  126.007           0
# 393          0.353000    0.1520   0.4860   92.218           0
# 418          0.000004    0.0566   0.3020  160.080           1
# 217          0.151000    0.0733   0.1460  194.008           1

# %%
# Cria o objeto
reco_obj = RecoSystem(df_final)

# %%
musica = df_musica_randomica['name'].tolist()[0]

# %%
print(musica)
# Out:
# Quarter

# %%
# Executa a recomendação
recomendacao = reco_obj.Recomm(musica)
# Out:
# 100%|██████████| 378/378 [00:00<00:00, 45182.30it/s]

# %%
# Extrai a música randômica da lista de favoritos do Spotify
y = df_musica_randomica[['id','name', 
                         'artists',  
                         'acousticness', 
                         'liveness', 
                         'instrumentalness', 
                         'energy', 
                         'danceability', 
                         'valence']]

# %%
# Concatena a recomendação com a música randômica da lista de favoritos do Spotify
recomendacao = pd.concat([recomendacao, y])

# %%
# Salva a recomendação em disco
recomendacao.to_csv('recomendacoes/recomendacao.csv')

# %%
# Carrega o arquivo do disco
df_reco = (spark.read.format("csv").options(header = "true").load("recomendacoes/recomendacao.csv"))

# %%
# Recomendação de música
df_reco.show()
# Out:
# +---+--------------------+--------+----------+------------+--------+----------------+------+------------+-------+
# |_c0|                  id|    name|   artists|acousticness|liveness|instrumentalness|energy|danceability|valence|
# +---+--------------------+--------+----------+------------+--------+----------------+------+------------+-------+
# |332|7khpPruHJK39VTBUQ...|Stranger|MildOrange|       0.412|   0.109|           0.113| 0.491|       0.334|  0.452|
# | 29|1niIoI0IVTswfNxdy...| Quarter|      Fuel|     0.00012|   0.254|           0.683|  0.93|       0.422|  0.201|
# +---+--------------------+--------+----------+------------+--------+----------------+------+------------+-------+

# %% [markdown]
# # Fim
